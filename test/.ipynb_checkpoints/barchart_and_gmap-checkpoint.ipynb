# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import gmaps

# %%
import requests
import json

# %%
Cities_DF = pd.read_csv("../Project_1/500_Cities__Obesity_among_adults_aged___18_years.csv")
Cities_DF.head()
# Out:
#    Year StateAbbr StateDesc     CityName GeographicLevel DataSource  \
# 0  2017        HI    Hawaii     Honolulu    Census Tract      BRFSS
# 1  2017        HI    Hawaii     Honolulu    Census Tract      BRFSS
# 2  2017        GA   Georgia      Roswell            City      BRFSS
# 3  2017        HI    Hawaii     Honolulu    Census Tract      BRFSS
# 4  2017        GA   Georgia  Johns Creek    Census Tract      BRFSS
#
#               Category             UniqueID  \
# 0  Unhealthy Behaviors          15003004600
# 1  Unhealthy Behaviors          15003001400
# 2  Unhealthy Behaviors              1367284
# 3  Unhealthy Behaviors          15003010801
# 4  Unhealthy Behaviors  1342425-13121011425
#
#                                 Measure Data_Value_Unit  ...  \
# 0  Obesity among adults aged >=18 Years               %  ...
# 1  Obesity among adults aged >=18 Years               %  ...
# 2  Obesity among adults aged >=18 Years               %  ...
# 3  Obesity among adults aged >=18 Years               %  ...
# 4  Obesity among adults aged >=18 Years               %  ...
#
#   High_Confidence_Limit Data_Value_Footnote_Symbol  Data_Value_Footnote  \
# 0                  18.0                        NaN                  NaN
# 1                  19.7                        NaN                  NaN
# 2                  23.9                        NaN                  NaN
# 3                  25.0                        NaN                  NaN
# 4                  21.9                        NaN                  NaN
#
#    PopulationCount                      GeoLocation CategoryID MeasureId  \
# 0            3,735  (21.3510749539, -157.825340793)     UNHBEH   OBESITY
# 1            2,550  (21.2772209725, -157.806213514)     UNHBEH   OBESITY
# 2           88,346  (34.0391384583, -84.3512225277)     UNHBEH   OBESITY
# 3            2,969  (21.4491051468, -157.761542724)     UNHBEH   OBESITY
# 4            6,906   (34.013011213, -84.2405514785)     UNHBEH   OBESITY
#
#     CityFIPS     TractFIPS Short_Question_Text
# 0    15003.0  1.500300e+10             Obesity
# 1    15003.0  1.500300e+10             Obesity
# 2  1367284.0           NaN             Obesity
# 3    15003.0  1.500301e+10             Obesity
# 4  1342425.0  1.312101e+10             Obesity
#
# [5 rows x 24 columns]

# %%
print(len(Cities_DF["CityName"].unique()))
# Out:
# 475

# %%
group= Cities_DF.groupby(["StateDesc","CityName"])
meanvalue = group["Data_Value"].mean()
meanvalue = pd.DataFrame(meanvalue).reset_index()

# %%
meanvalue
# Out:
#      StateDesc    CityName  Data_Value
# 0      Alabama  Birmingham   40.329348
# 1      Alabama      Hoover   29.160000
# 2      Alabama  Huntsville   35.896667
# 3      Alabama      Mobile   38.803896
# 4      Alabama  Montgomery   39.204839
# ..         ...         ...         ...
# 495  Wisconsin     Madison   26.304478
# 496  Wisconsin   Milwaukee   35.874299
# 497  Wisconsin      Racine   39.504167
# 498  Wisconsin    Waukesha   30.763636
# 499    Wyoming    Cheyenne   29.205556
#
# [500 rows x 3 columns]

# %%
USDA = pd.read_csv('../data/USDA_Farmers_Market.csv')
USDA.head()
# Out:
#       FMID                                        MarketName  \
# 0  1018261   Caledonia Farmers Market Association - Danville
# 1  1018318                 Stearns Homestead Farmers' Market
# 2  1009364                 106 S. Main Street Farmers Market
# 3  1010691               10th Steet Community Farmers Market
# 4  1002454                              112st Madison Avenue
#
#                                              Website  \
# 0  https://sites.google.com/site/caledoniafarmers...
# 1                    http://www.StearnsHomestead.com
# 2             http://thetownofsixmile.wordpress.com/
# 3                                                NaN
# 4                                                NaN
#
#                                             Facebook Twitter Youtube  \
# 0  https://www.facebook.com/Danville.VT.Farmers.M...     NaN     NaN
# 1                      StearnsHomesteadFarmersMarket     NaN     NaN
# 2                                                NaN     NaN     NaN
# 3                                                NaN     NaN     NaN
# 4                                                NaN     NaN     NaN
#
#                                           OtherMedia                  street  \
# 0                                                NaN                     NaN
# 1                                                NaN         6975 Ridge Road
# 2                                                NaN      106 S. Main Street
# 3  http://agrimissouri.com/mo-grown/grodetail.php...  10th Street and Poplar
# 4                                                NaN    112th Madison Avenue
#
#    CityName     county  ... Coffee Beans Fruits Grains Juices Mushrooms  \
# 0  Danville  Caledonia  ...      Y     Y      Y      N      N         Y
# 1     Parma   Cuyahoga  ...      N     N      Y      N      N         N
# 2  Six Mile        NaN  ...    NaN   NaN    NaN    NaN    NaN       NaN
# 3     Lamar     Barton  ...      N     N      Y      N      N         N
# 4  New York   New York  ...      N     N      N      N      N         N
#
#   PetFood Tofu WildHarvested     updateTime
# 0       Y    N             N  6/20/17 22:43
# 1       N    N             N  6/21/17 17:15
# 2     NaN  NaN           NaN           2013
# 3       N    N             N  10/28/14 9:49
# 4       N    N             N   3/1/12 10:38
#
# [5 rows x 59 columns]

# %%
merged_df = USDA.merge(meanvalue, how = 'left', on = ['CityName', 'StateDesc'])
merged_df=merged_df.dropna(subset=["Data_Value"])
merged_df
# Out:
#          FMID                                   MarketName  \
# 1     1018318            Stearns Homestead Farmers' Market
# 4     1002454                         112st Madison Avenue
# 5     1011100                      12 South Farmers Market
# 6     1009845   125th Street Fresh Connect Farmers' Market
# 7     1005586          12th & Brandywine Urban Farm Market
# ...       ...                                          ...
# 8791  1019247  Your Neighborhood Farmers Market-CityCentre
# 8794  1019250  Your Neighborhood Farmers Market-Summerwood
# 8798  1007324                                Youth Stands!
# 8799  1007325                                Youth Stands!
# 8815  1011418                    Zona Rosa Farmers' Market
#
#                                            Website  \
# 1                  http://www.StearnsHomestead.com
# 4                                              NaN
# 5              http://www.12southfarmersmarket.com
# 6          http://www.125thStreetFarmersMarket.com
# 7                                              NaN
# ...                                            ...
# 8791  http://www.YourNeighborhoodFarmersMarket.com
# 8794  http://www.YourNeighborhoodFarmersMarket.com
# 8798                http://www.urbangreenworks.org
# 8799                http://www.urbangreenworks.org
# 8815                                           NaN
#
#                                                Facebook  \
# 1                         StearnsHomesteadFarmersMarket
# 4                                                   NaN
# 5                               12_South_Farmers_Market
# 6     https://www.facebook.com/125thStreetFarmersMarket
# 7     https://www.facebook.com/pages/12th-Brandywine...
# ...                                                 ...
# 8791  https://www.facebook.com/yourneighborhoodfarme...
# 8794  https://www.facebook.com/yourneighborhoodfarme...
# 8798                                                NaN
# 8799                                                NaN
# 8815                                                NaN
#
#                                   Twitter Youtube  \
# 1                                     NaN     NaN
# 4                                     NaN     NaN
# 5                         @12southfrmsmkt     NaN
# 6     https://twitter.com/FarmMarket125th     NaN
# 7                                     NaN     NaN
# ...                                   ...     ...
# 8791                                  NaN     NaN
# 8794                                  NaN     NaN
# 8798                                  NaN     NaN
# 8799                                  NaN     NaN
# 8815                                  NaN     NaN
#
#                                              OtherMedia  \
# 1                                                   NaN
# 4                                                   NaN
# 5                                       @12southfrmsmkt
# 6                 Instagram--> 125thStreetFarmersMarket
# 7     https://www.facebook.com/delawareurbanfarmcoal...
# ...                                                 ...
# 8791                                                NaN
# 8794                                                NaN
# 8798                                                NaN
# 8799                                                NaN
# 8815                                                NaN
#
#                                                  street       CityName  \
# 1                                       6975 Ridge Road          Parma
# 4                                  112th Madison Avenue       New York
# 5                                3000 Granny White Pike      Nashville
# 6     163 West 125th Street and Adam Clayton Powell,...       New York
# 7                             12th & Brandywine Streets     Wilmington
# ...                                                 ...            ...
# 8791                         800 Towne and County BLVD.        Houston
# 8794                    14303 West Lake Houston Parkway        Houston
# 8798                                    8240 NW 7th Ave          Miami
# 8799                                  15700 NW 20th Ave  Miami Gardens
# 8815                         Off of I-29 and Barry Road    Kansas City
#
#           county  ... Beans Fruits Grains Juices Mushrooms PetFood Tofu  \
# 1       Cuyahoga  ...     N      Y      N      N         N       N    N
# 4       New York  ...     N      N      N      N         N       N    N
# 5       Davidson  ...     N      Y      N      Y         Y       Y    N
# 6       New York  ...     N      Y      N      Y         N       N    N
# 7     New Castle  ...     N      Y      N      N         N       N    N
# ...          ...  ...   ...    ...    ...    ...       ...     ...  ...
# 8791      Harris  ...     N      Y      N      Y         N       Y    N
# 8794      Harris  ...     Y      Y      Y      Y         N       Y    N
# 8798  Miami-Dade  ...     N      N      N      N         N       N    N
# 8799  Miami-Dade  ...     N      N      N      N         N       N    N
# 8815      Platte  ...     N      Y      N      N         N       N    N
#
#      WildHarvested     updateTime Data_Value
# 1                N  6/21/17 17:15  29.037500
# 4                N   3/1/12 10:38  25.034450
# 5                N   5/1/15 10:40  31.698101
# 6                N   4/7/14 16:32  25.034450
# 7                N   4/3/14 15:43  39.573077
# ...            ...            ...        ...
# 8791             Y   9/6/18 17:06  34.130144
# 8794             Y   9/6/18 17:23  34.130144
# 8798             N  5/22/12 23:19  33.482524
# 8799             N  5/22/12 23:19  37.864000
# 8815             N    9/4/15 9:48  36.167949
#
# [1813 rows x 60 columns]

# %%
fig1, ax1 = plt.subplots()
ax1.boxplot(merged_df["Data_Value"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a265474d0>,
#   <matplotlib.lines.Line2D at 0x1a26547a10>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a26547f10>,
#   <matplotlib.lines.Line2D at 0x1a26532850>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a26532810>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a26554990>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1
# 1928                                   http://pcfma.org
# 1929  http://www.pcfma.com/market_home.php?market_id=63
# 2703                               http://www.cuesa.org
# 2805  http://www.cafarmersmkts.com/markets/category/...
# 2875                                                NaN
# 2935                 http://www.fullcirclesunnyvale.org
# 3061                                   http://pcfma.org
# 3511                   http://www.hotcfarmersmarket.org
# 3825                                   http://pcfma.org
# 3844                        http://www.ocfarmbureau.org
# 3849                     http://www.pcfma.com/irvington
# 3981  http://www.pcfma.com/market_home.php?market_id=33
# 3991                               http://www.pcfma.org
# 3994                                   http://pcfma.org
# 5032                               http://www.pcfma.org
# 5058                                                NaN
# 5060                                   http://pcfma.org
# 5061              http://www.missioncommunitymarket.org
# 5446             http://www.noevalleyfarmersmarket.com/
# 5466                          http://www.urbantable.org
# 5910                                   http://pcfma.org
# 6726                          http://www.thecannery.com
# 6727                                                NaN
# 6728  http://www.cafarmersmkts.com/markets/category/...
# 6729                       http://www.cafarmersmkts.com
# 6730                                   http://pcfma.org
# 6736                  http://www.urbanvillageonline.com
# 6775                  http://www.urbanvillageonline.com
# 6883                          http://www.urbantable.org
# 7341  https://www.agriculturalinstitute.org/director...
# 7414                  http://www.urbanvillageonline.com
# 7608                        http://www.orange.cfbf.com/
# 7826                                                NaN
# 7988                                                NaN
# 7992                                   http://pcfma.org
# 8041                                   http://pcfma.org
# 8042                               http://www.pcfma.com
# 8773                          http://www.urbantable.org
#
#                                                Facebook  \
# 715   www.facebook.com/Boulder-Farmers-Market-512016...
# 1121                   facebook.com/CastroFarmersMarket
# 1437  https://www.facebook.com/ClementStreetFarmersM...
# 1798              https://www.Facebook.com/DCFarmersMkt
# 1928               facebook.com/DivisaderoFarmersMarket
# 1929                                                NaN
# 2703      https://www.facebook.com/CUESA/?ref=bookmarks
# 2805             https://www.Facebook.com/FMCFarmersMkt
# 2875                                                NaN
# 2935                                                NaN
# 3061          facebook.com/GlenParkVillageFarmersMarket
# 3511  https://www.facebook.com/pages/Heart-of-the-Ci...
# 3825                     facebook.com/InnerSunsetMarket
# 3844                     OC Farm Bureau Farmers Markets
# 3849           https://www.facebook.com/IrvingtonMarket
# 3981                                                NaN
# 3991                                                NaN
# 3994                                                NaN
# 5032             www.facebook.com/MilpitasFarmersMarket
# 5058                                                NaN
# 5060               facebook.com/MissionBayFarmersMarket
# 5061                                                NaN
# 5446                                                NaN
# 5466                                                NaN
# 5910                                                NaN
# 6726                                                NaN
# 6727                                                NaN
# 6728              https://www.Facebook.com/SFFarmersMkt
# 6729                                                NaN
# 6730                 facebook.com/FillmoreFarmersMarket
# 6736                                                NaN
# 6775                                                NaN
# 6883                                                NaN
# 7341  https://www.facebook.com/StonestownFarmersMark...
# 7414                                                NaN
# 7608                                                NaN
# 7826                                                NaN
# 7988                                                NaN
# 7992              facebook.com/UpperHaightFarmersMarket
# 8041                                                NaN
# 8042                                                NaN
# 8773                                                NaN
#
#                                 Twitter Youtube  \
# 715      www.twitter.com/bldrfarmersmkt     NaN
# 1121        twitter.com/PacCoastFarmers     NaN
# 1437                                NaN     NaN
# 1798  https://twitter.com/cafarmersmkts     NaN
# 1928        twitter.com/PacCoastFarmers     NaN
# 1929                                NaN     NaN
# 2703                             @cuesa     NaN
# 2805  https://twitter.com/cafarmersmkts     NaN
# 2875                                NaN     NaN
# 2935                                NaN     NaN
# 3061        twitter.com/PacCoastFarmers     NaN
# 3511                                NaN     NaN
# 3825        twitter.com/PacCoastFarmers     NaN
# 3844                                NaN     NaN
# 3849                                NaN     NaN
# 3981                                NaN     NaN
# 3991    www.twitter.com/PacCoastFarmers     NaN
# 3994        twitter.com/PacCoastFarmers     NaN
# 5032    www.twitter.com/PacCoastFarmers     NaN
# 5058                                NaN     NaN
# 5060        twitter.com/PacCoastFarmers     NaN
# 5061                                NaN     NaN
# 5446                                NaN     NaN
# 5466                                NaN     NaN
# 5910        twitter.com/PacCoastFarmers     NaN
# 6726                                NaN     NaN
# 6727                                NaN     NaN
# 6728  https://twitter.com/cafarmersmkts     NaN
# 6729                                NaN     NaN
# 6730        twitter.com/PacCoastFarmers     NaN
# 6736                                NaN     NaN
# 6775                                NaN     NaN
# 6883                                NaN     NaN
# 7341                                NaN     NaN
# 7414                                NaN     NaN
# 7608                                NaN     NaN
# 7826                                NaN     NaN
# 7988                                NaN     NaN
# 7992        twitter.com/PacCoastFarmers     NaN
# 8041        twitter.com/PacCoastFarmers     NaN
# 8042                                NaN     NaN
# 8773                                NaN     NaN
#
#                                    OtherMedia  \
# 715    www.instagram.com/boulderfarmersmarket
# 1121                      instagram.com/pcfma
# 1437                                      NaN
# 1798  http://www.pinterest.com/cafarmersmkts/
# 1928                      instagram.com/pcfma
# 1929                                      NaN
# 2703                                   @cuesa
# 2805  http://www.pinterest.com/cafarmersmkts/
# 2875                                      NaN
# 2935                                      NaN
# 3061                      instagram.com/pcfma
# 3511                                      NaN
# 3825                      instagram.com/pcfma
# 3844                                      NaN
# 3849                                      NaN
# 3981                                      NaN
# 3991                                      NaN
# 3994                      instagram.com/pcfma
# 5032                                      NaN
# 5058                                      NaN
# 5060                      instagram.com/pcfma
# 5061                                      NaN
# 5446                                      NaN
# 5466                                      NaN
# 5910                      instagram.com/pcfma
# 6726                                      NaN
# 6727                                      NaN
# 6728  http://www.pinterest.com/cafarmersmkts/
# 6729                                      NaN
# 6730                      instagram.com/pcfma
# 6736                                      NaN
# 6775                                      NaN
# 6883                                      NaN
# 7341                                      NaN
# 7414                                      NaN
# 7608                                      NaN
# 7826                                      NaN
# 7988                                      NaN
# 7992                      instagram.com/pcfma
# 8041                      instagram.com/pcfma
# 8042                                      NaN
# 8773                                      NaN
#
#                                                  street       CityName  \
# 715                   Canyon Boulevard and 13th Street         Boulder
# 1121                             Noe St. and Market St.  San Francisco
# 1437                    Clement St. between 2nd and 4th  San Francisco
# 1798                       Hwy 280 and Serramonte Blvd.      Daly City
# 1928                       Grove St. and Divisadero St.  San Francisco
# 6736           NaN           2009  16.762222
# 6775             N   5/1/12 17:58  17.634615
# 6883             N  5/19/12 10:25  18.046701
# 7341             N  7/13/16 13:44  18.046701
# 7414             N   5/1/12 17:45  16.900000
# 7608             N  4/25/12 15:15  16.121622
# 7826             N  4/26/12 13:51  17.953125
# 7988           NaN           2011  18.046701
# 7992             N  7/20/15 12:39  18.046701
# 8041             N  7/23/15 16:51  18.046701
# 8042             N  6/14/12 14:44  18.046701
# 8773             N  5/19/12 10:22  18.046701
#
# [42 rows x 60 columns]

# %%
meanvalue.loc[(meanvalue["Data_Value"]<=18.04670050761421)]
# Out:
#       StateDesc       CityName  Data_Value
# 25   California       Alhambra   17.754545
# 47   California      Daly City   17.422727
# 56   California        Fremont   16.762222
# 68   California         Irvine   16.121622
# 79   California       Milpitas   15.800000
# 112  California  San Francisco   18.046701
# 120  California    Santa Clara   17.634615
# 128  California      Sunnyvale   16.900000
# 131  California       Torrance   17.953125
# 147    Colorado        Boulder   15.383333

# %%
c_merged_df= merged_df.drop(columns=["FMID","Website","Facebook","Twitter","Youtube","OtherMedia","street","updateTime",
                                   "Season1Date","Season1Time","Season2Date","Season2Time","Season3Date","Season3Time",
                                    "Season4Date","Season4Time",'Location', 'Credit', 'WIC', 'WICcash'])

# %%
#10%
top = c_merged_df.loc[(c_merged_df["Data_Value"]>=38.289772998805226)]
low = c_merged_df.loc[(c_merged_df["Data_Value"]<=22.525)]

# %%
low["Fruits"].value_counts()
# Out:
# Y    121
# N     27
# Name: Fruits, dtype: int64

# %%
top["Fruits"].value_counts()
# Out:
# Y    117
# N     28
# Name: Fruits, dtype: int64

# %%
USDA.loc[(USDA["street"].isnull())]
# Out:
#          FMID                                        MarketName  \
# 0     1018261   Caledonia Farmers Market Association - Danville
# 46    1008391                   84 west farmers market (Dothan)
# 69    1002108               Acadia Farmers' Market in Town Hill
# 233   1018356                      Appleton Area Farmers Market
# 365   1001695                     Ausable Valley Farmers Market
# ...       ...                                               ...
# 8760  1000416                           Yarker at Beach Gardens
# 8772  1003519                           Yemassee Farmers Market
# 8774  1001790                Yesterday's Farmers-Kustom Gardens
# 8777  2000036                YMCA Farmers Market and Veggie Van
# 8785  1006423               York Gateway Winter Farmers' Market
#
#                                                 Website  \
# 0     https://sites.google.com/site/caledoniafarmers...
# 46                                                  NaN
# 69                                                  NaN
# 233                                                 NaN
# 365                                                 NaN
# ...                                                 ...
# 8760                                                NaN
# 8772                                                NaN
# 8774                                                NaN
# 8777  http://mi.marketmaker.uiuc.edu/business/162766...
# 8785                http://www.gatewayfarmersmarket.com
#
#                                                Facebook Twitter Youtube  \
# 0     https://www.facebook.com/Danville.VT.Farmers.M...     NaN     NaN
# 46                                                  NaN     NaN     NaN
# 69                 www.Facebook.com/AcadiaFarmersMarket     NaN     NaN
# 233                                                 NaN     NaN     NaN
# 365   https://www.facebook.com/pages/Ausable-Valley-...     NaN     NaN
# ...                                                 ...     ...     ...
# 8760                                                NaN     NaN     NaN
# 8772                                                NaN     NaN     NaN
# 8774                                                NaN     NaN     NaN
# 8777  https://www.facebook.com/pages/YMCA-Farmers-Ma...     NaN     NaN
# 8785  https://www.facebook.com/YorkGatewayFarmersMarket     NaN     NaN
#
#      OtherMedia street       CityName         county  ... Coffee Beans Fruits  \
# 0           NaN    NaN       Danville      Caledonia  ...      Y     Y      Y
# 46          NaN    NaN         Dothan        Houston  ...      N     N      Y
# 69          NaN    NaN      Town Hill        Hancock  ...    NaN   NaN    NaN
# 233         NaN    NaN       Appleton          Swift  ...      N     N      Y
# 365         NaN    NaN  Ausable Forks          Essex  ...      N     N      N
# ...         ...    ...            ...            ...  ...    ...   ...    ...
# 8760        NaN    NaN          Beach  Golden Valley  ...    NaN   NaN    NaN
# 8772        NaN    NaN       Yemassee        Hampton  ...    NaN   NaN    NaN
# 8774        NaN    NaN         Bowman          Adams  ...    NaN   NaN    NaN
# 8777        NaN    NaN            NaN            NaN  ...    NaN   NaN    NaN
# 8785        NaN    NaN           York           York  ...      N     N      Y
#
#      Grains Juices Mushrooms PetFood Tofu WildHarvested     updateTime
# 0         N      N         Y       Y    N             N  6/20/17 22:43
# 46        N      N         N       N    N             N   3/15/14 9:29
# 69      NaN    NaN       NaN     NaN  NaN           NaN           2009
# 233       N      N         N       N    N             N  6/22/17 17:03
# 365       N      N         N       N    N             N  4/18/11 20:17
# ...     ...    ...       ...     ...  ...           ...            ...
# 8760    NaN    NaN       NaN     NaN  NaN           NaN           2009
# 8772    NaN    NaN       NaN     NaN  NaN           NaN           2009
# 8774    NaN    NaN       NaN     NaN  NaN           NaN           2009
# 8777    NaN    NaN       NaN     NaN  NaN           NaN           2013
# 8785      N      Y         N       Y    N             Y  4/15/15 10:48
#
# [288 rows x 59 columns]

# %%
group_low = low.set_index("CityName").groupby("CityName")
group_top = top.set_index("CityName").groupby("CityName")

# %%
group_low["Organic"].value_counts().unstack().plot.bar(stacked=True,figsize=(30,9))
plt.title("Organic in Farmer Market of 10% of low obeisity value city")
#plt.savefig("../image/Organic_low.png")
plt.show()

# %%
group_top["Organic"].value_counts().unstack().plot.bar(stacked=True,figsize=(30,9))
plt.title("Organic in Farmer Market of 10% of top obeisity value city")
plt.savefig("../image/Organic_top.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-0034365fae3d> in <module>
#       1 group_top["Organic"].value_counts().unstack().plot.bar(stacked=True,figsize=(30,9))
#       2 plt.title("Organic in Farmer Market of 10% of top obeisity value city")
# ----> 3 plt.savefig("../image/Organic_top.png")
#       4 plt.show()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     727 def savefig(*args, **kwargs):
#     728     fig = gcf()
# --> 729     res = fig.savefig(*args, **kwargs)
#     730     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     731     return res
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2089                     orientation=orientation,
#    2090                     bbox_inches_restore=_bbox_inches_restore,
# -> 2091                     **kwargs)
#    2092             finally:
#    2093                 if bbox_inches and restore_bbox:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
# --> 530                     cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     531                 _png.write_png(renderer._renderer, fh,
#     532                                self.figure.dpi, metadata=metadata)
#
# /opt/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     445 def open_file_cm(path_or_file, mode="r", encoding=None):
#     446     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 447     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     448     if opened:
#     449         with fh:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     430             fh = bz2.BZ2File(fname, flag)
#     431         else:
# --> 432             fh = open(fname, flag, encoding=encoding)
#     433         opened = True
#     434     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../image/Organic_top.png'

# %%
group_low["Vegetables"].value_counts().unstack().plot.bar(stacked=True,figsize=(30,9))
plt.title("Vegetables in Farmer Market of 10% of low obeisity value city")
plt.savefig("../image/Vegetables_low.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-4af8e911868f> in <module>
#       1 group_low["Vegetables"].value_counts().unstack().plot.bar(stacked=True,figsize=(30,9))
#       2 plt.title("Vegetables in Farmer Market of 10% of low obeisity value city")
# ----> 3 plt.savefig("../image/Vegetables_low.png")
#       4 plt.show()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     727 def savefig(*args, **kwargs):
#     728     fig = gcf()
# --> 729     res = fig.savefig(*args, **kwargs)
#     730     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     731     return res
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2089                     orientation=orientation,
#    2090                     bbox_inches_restore=_bbox_inches_restore,
# -> 2091                     **kwargs)
#    2092             finally:
#    2093                 if bbox_inches and restore_bbox:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
# --> 530                     cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     531                 _png.write_png(renderer._renderer, fh,
#     532                                self.figure.dpi, metadata=metadata)
#
# /opt/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     445 def open_file_cm(path_or_file, mode="r", encoding=None):
#     446     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 447     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     448     if opened:
#     449         with fh:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     430             fh = bz2.BZ2File(fname, flag)
#     431         else:
# --> 432             fh = open(fname, flag, encoding=encoding)
#     433         opened = True
#     434     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../image/Vegetables_low.png'

# %%
group_top["Vegetables"].value_counts().unstack().plot.bar(stacked=True,figsize=(30,9))
plt.title("Vegetables in Farmer Market of 10% of top obeisity value city")
plt.savefig("../image/Vegetables_top.png")
plt.show()

# %%
from config import gkey
gmaps.configure(api_key=gkey)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-1ea5c460c8bb> in <module>
# ----> 1 from config import gkey
#       2 gmaps.configure(api_key=gkey)
#
# ModuleNotFoundError: No module named 'config'

# %%
def getLoca(df):
    df = df.reset_index()
    df["lat"]=""
    df["lng"]=""
    for index, row in df.iterrows():
        target_city = row["CityName"]+","+row["StateDesc"]
        target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
            'address={0}&key={1}').format(target_city, gkey)
        geo_data = requests.get(target_url).json()
        lat = geo_data["results"][0]["geometry"]["location"]["lat"]
        lng = geo_data["results"][0]["geometry"]["location"]["lng"]
        df.loc[index,"lat"]= lat
        df.loc[index,"lng"]= lng
    return df

# %%
#1% of obeisity
top1 = meanvalue.loc[(meanvalue["Data_Value"]>=44.11428571428572)]
low1 = meanvalue.loc[(meanvalue["Data_Value"]<=18.04670050761421)]

# %%
#1%
C_low1 = low1
C_top1 = top1

# %%
#Add marker of 1% low in map
C_low1 = getLoca(C_low1)
locations = C_low1[["lat", "lng"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-9befad663a2b> in <module>
#       1 #Add marker of 1% low in map
# ----> 2 C_low1 = getLoca(C_low1)
#       3 locations = C_low1[["lat", "lng"]]
#
# <ipython-input-23-862cf7e4b2fc> in getLoca(df)
#       6         target_city = row["CityName"]+","+row["StateDesc"]
#       7         target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
# ----> 8             'address={0}&key={1}').format(target_city, gkey)
#       9         geo_data = requests.get(target_url).json()
#      10         lat = geo_data["results"][0]["geometry"]["location"]["lat"]
#
# NameError: name 'gkey' is not defined

# %%
info_box_template = """
<dl>
<dt>Number</dt><dd>{Data_Value}</dd>
<dt>City</dt><dd>{CityName}</dd>
<dt>State</dt><dd>{StateDesc}</dd>
</dl>
"""
city_info = [info_box_template.format(**row) for index, row in C_low1.iterrows()]
locations = C_low1[["lat", "lng"]]

# %%
fig = gmaps.figure()
marker_layer = gmaps.marker_layer(locations,info_box_content=city_info)
fig.add_layer(marker_layer)
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Add marker of 1% top in map
C_top1 = getLoca(C_top1)
city_info2 = [info_box_template.format(**row) for index, row in C_top1.iterrows()]
locations2 = C_top1[["lat", "lng"]]
marker_layer2 = gmaps.marker_layer(locations2,info_box_content=city_info2,display_info_box=True)

fig.add_layer(marker_layer2)
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#add point
top_layer = gmaps.symbol_layer(
    locations2, fill_color="red",
    stroke_color="red", scale=5
)

low_layer = gmaps.symbol_layer(
    locations, fill_color="black",
    stroke_color="black", scale=5
)
fig.add_layer(top_layer)
fig.add_layer(low_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Map for total number of Farmers Market in US cities
Total_farmer = pd.DataFrame(USDA.groupby(['CityName', 'StateDesc'])['FMID'].count())

# %%
'''Total_farmer = getLoca(Total_farmer)
over 6000 row
Total_farmer.to_csv("total.csv")'''
Total_farmer = pd.read_csv("total.csv")

# %%
locations = Total_farmer[["lat", "lng"]]
rating = Total_farmer["FMID"].astype(float)

# %%
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False,
                                 point_radius=1)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Map for 10% low with number of farmer Markte
C_low = pd.DataFrame(low1.groupby(["CityName","StateDesc"]).size())
C_low = C_low.rename(columns={0:"total"})
C_low = getLoca(C_low)

# %%
locations = C_top[["lat", "lng"]]
rating = C_top["total"].astype(float)
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False,
                                 point_radius=1)

fig.add_layer(heat_layer)
fig

# %%
#Map for 10% top with number of farmer Markte
C_top = pd.DataFrame(top.groupby(["CityName","StateDesc"]).size())
C_top = C_top.rename(columns={0:"total"})
C_top = getLoca(C_top)

# %%
locations = C_top[["lat", "lng"]]
rating = C_top["total"].astype(float)
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False,
                                 point_radius=1)

fig.add_layer(heat_layer)
fig

# %%
#Map for Obeisity rate US
C_meanvalue = meanvalue
C_meanvalue = getLoca(C_meanvalue)

# %%
locations = C_meanvalue[["lat", "lng"]]
rating = C_meanvalue["Data_Value"].astype(float)
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False,
                                 point_radius=1)
fig.add_layer(heat_layer)
fig

# %%
group_top["Fruits"].value_counts().unstack().plot.bar(stacked=True,figsize=(30,9))
plt.title("Fruits in Farmer Market of 10% of top obeisity value city")
#plt.savefig("../image/Fruits_top.png")
plt.show()

# %%
group_low["Fruits"].value_counts().unstack().plot.bar(stacked=True,figsize=(30,9))
plt.title("Fruits in Farmer Market of 10% of low obeisity value city")
#plt.savefig("../image/Fruits_low.png")
plt.show()

# %%
group_top["WildHarvested"].value_counts().unstack().plot.bar(stacked=True,figsize=(30,9))
plt.title("WildHarvested in Farmer Market of 10% of top obeisity value city")
#plt.savefig("../image/WildHarvested_top.png")
plt.show()

# %%
group_low["WildHarvested"].value_counts().unstack().plot.bar(stacked=True,figsize=(30,9))
plt.title("WildHarvested in Farmer Market of 10% of low obeisity value city")
#plt.savefig("../image/WildHarvested_low.png")
plt.show()

# %%
group_top["Honey"].value_counts().unstack().plot.bar(stacked=True,figsize=(30,9))
plt.title("Honey in Farmer Market of 10% of top obeisity value city")
#plt.savefig("../image/Honey_top.png")
plt.show()

# %%
group_low["Honey"].value_counts().unstack().plot.bar(stacked=True,figsize=(30,9))
plt.title("Honey in Farmer Market of 10% of low obeisity value city")
#plt.savefig("../image/Honey_low.png")
plt.show()

# %%
group_top["Jams"].value_counts().unstack().plot.bar(stacked=True,figsize=(30,9))
plt.title("Jams in Farmer Market of 10% of top obeisity value city")
#plt.savefig("../image/Jams_top.png")
plt.show()

# %%
group_low["Jams"].value_counts().unstack().plot.bar(stacked=True,figsize=(30,9))
plt.title("Jams in Farmer Market of 10% of low obeisity value city")
#plt.savefig("../image/Jams_low.png")
plt.show()

# %%
group_top["Nuts"].value_counts().unstack().plot.bar(stacked=True,figsize=(30,9))
plt.title("Nuts in Farmer Market of 10% of top obeisity value city")
#plt.savefig("../image/Nuts_top.png")
plt.show()

# %%
group_low["Nuts"].value_counts().unstack().plot.bar(stacked=True,figsize=(30,9))
plt.title("Nuts in Farmer Market of 10% of low obeisity value city")
#plt.savefig("../image/Nuts_low.png")
plt.show()

# %%
group = c_merged_df.set_index("CityName").groupby(["StateDesc","CityName"])

# %%
number = pd.DataFrame(group['MarketName'].count()).reset_index()

# %%
M_O_merge = pd.merge(number, meanvalue, on=["StateDesc","CityName"])

# %%
plt.scatter(M_O_merge["Data_Value"], M_O_merge["MarketName"], marker="o", facecolors="red", edgecolors="black",alpha=0.75)

# %%
#scatter plot
x_value = M_O_merge["MarketName"]
y_value = M_O_merge["Data_Value"]
correlation = st.pearsonr(x_value,y_value)
print(f"The correlation between MarketName and Data_Value is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr)=st.linregress(x_value,y_value)
regress_value = x_value*slope+intercept
plt.scatter(x_value,y_value)
plt.plot(x_value, regress_value, "r-")
'''line_eq = f"y={round(slope,2)}x+{round(intercept,2)}"
plt.annotate(line_eq,(min(x_value),min(y_value)),fontsize=15,color="red")'''
#plt.text(.5,.5,f"The correlation is {round(correlation[0],2)}")
plt.title("Obesity vs Number of Farmer Market")
plt.xlabel("Total Number of Farmer Market per City")
plt.ylabel("Obesity (%)")
#plt.savefig("../image/Scatter_OF.png")
plt.show()
# Out:
# The correlation between MarketName and Data_Value is 0.05
