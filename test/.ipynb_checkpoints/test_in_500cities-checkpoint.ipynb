# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
base = pd.read_csv("../Project_1/500_Cities__Obesity_among_adults_aged___18_years.csv")
base.head()
# Out:
#    Year StateAbbr StateDesc     CityName GeographicLevel DataSource  \
# 0  2017        HI    Hawaii     Honolulu    Census Tract      BRFSS
# 1  2017        HI    Hawaii     Honolulu    Census Tract      BRFSS
# 2  2017        GA   Georgia      Roswell            City      BRFSS
# 3  2017        HI    Hawaii     Honolulu    Census Tract      BRFSS
# 4  2017        GA   Georgia  Johns Creek    Census Tract      BRFSS
#
#               Category             UniqueID  \
# 0  Unhealthy Behaviors          15003004600
# 1  Unhealthy Behaviors          15003001400
# 2  Unhealthy Behaviors              1367284
# 3  Unhealthy Behaviors          15003010801
# 4  Unhealthy Behaviors  1342425-13121011425
#
#                                 Measure Data_Value_Unit  ...  \
# 0  Obesity among adults aged >=18 Years               %  ...
# 1  Obesity among adults aged >=18 Years               %  ...
# 2  Obesity among adults aged >=18 Years               %  ...
# 3  Obesity among adults aged >=18 Years               %  ...
# 4  Obesity among adults aged >=18 Years               %  ...
#
#   High_Confidence_Limit Data_Value_Footnote_Symbol  Data_Value_Footnote  \
# 0                  18.0                        NaN                  NaN
# 1                  19.7                        NaN                  NaN
# 2                  23.9                        NaN                  NaN
# 3                  25.0                        NaN                  NaN
# 4                  21.9                        NaN                  NaN
#
#    PopulationCount                      GeoLocation CategoryID MeasureId  \
# 0            3,735  (21.3510749539, -157.825340793)     UNHBEH   OBESITY
# 1            2,550  (21.2772209725, -157.806213514)     UNHBEH   OBESITY
# 2           88,346  (34.0391384583, -84.3512225277)     UNHBEH   OBESITY
# 3            2,969  (21.4491051468, -157.761542724)     UNHBEH   OBESITY
# 4            6,906   (34.013011213, -84.2405514785)     UNHBEH   OBESITY
#
#     CityFIPS     TractFIPS Short_Question_Text
# 0    15003.0  1.500300e+10             Obesity
# 1    15003.0  1.500300e+10             Obesity
# 2  1367284.0           NaN             Obesity
# 3    15003.0  1.500301e+10             Obesity
# 4  1342425.0  1.312101e+10             Obesity
#
# [5 rows x 24 columns]

# %%
print(len(base["CityName"].unique()))
# Out:
# 475

# %%
base["Data_Value"]=base["Data_Value"].str.replace(',', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-95163e97dd95> in <module>
# ----> 1 base["Data_Value"]=base["Data_Value"].str.replace(',', '').astype(int)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # http://www.pydanny.com/cached-property.html
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py in __init__(self, data)
#    2037
#    2038     def __init__(self, data):
# -> 2039         self._inferred_dtype = self._validate(data)
#    2040         self._is_categorical = is_categorical_dtype(data)
#    2041         self._is_string = data.dtype.name == "string"
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py in _validate(data)
#    2094
#    2095         if inferred_dtype not in allowed_types:
# -> 2096             raise AttributeError("Can only use .str accessor with string values!")
#    2097         return inferred_dtype
#    2098
#
# AttributeError: Can only use .str accessor with string values!

# %%
base.head()
# Out:
#    Year StateAbbr StateDesc     CityName GeographicLevel DataSource  \
# 0  2017        HI    Hawaii     Honolulu    Census Tract      BRFSS
# 1  2017        HI    Hawaii     Honolulu    Census Tract      BRFSS
# 2  2017        GA   Georgia      Roswell            City      BRFSS
# 3  2017        HI    Hawaii     Honolulu    Census Tract      BRFSS
# 4  2017        GA   Georgia  Johns Creek    Census Tract      BRFSS
#
#               Category             UniqueID  \
# 0  Unhealthy Behaviors          15003004600
# 1  Unhealthy Behaviors          15003001400
# 2  Unhealthy Behaviors              1367284
# 3  Unhealthy Behaviors          15003010801
# 4  Unhealthy Behaviors  1342425-13121011425
#
#                                 Measure Data_Value_Unit  ...  \
# 0  Obesity among adults aged >=18 Years               %  ...
# 1  Obesity among adults aged >=18 Years               %  ...
# 2  Obesity among adults aged >=18 Years               %  ...
# 3  Obesity among adults aged >=18 Years               %  ...
# 4  Obesity among adults aged >=18 Years               %  ...
#
#   High_Confidence_Limit Data_Value_Footnote_Symbol  Data_Value_Footnote  \
# 0                  18.0                        NaN                  NaN
# 1                  19.7                        NaN                  NaN
# 2                  23.9                        NaN                  NaN
# 3                  25.0                        NaN                  NaN
# 4                  21.9                        NaN                  NaN
#
#    PopulationCount                      GeoLocation CategoryID MeasureId  \
# 0            3,735  (21.3510749539, -157.825340793)     UNHBEH   OBESITY
# 1            2,550  (21.2772209725, -157.806213514)     UNHBEH   OBESITY
# 2           88,346  (34.0391384583, -84.3512225277)     UNHBEH   OBESITY
# 3            2,969  (21.4491051468, -157.761542724)     UNHBEH   OBESITY
# 4            6,906   (34.013011213, -84.2405514785)     UNHBEH   OBESITY
#
#     CityFIPS     TractFIPS Short_Question_Text
# 0    15003.0  1.500300e+10             Obesity
# 1    15003.0  1.500300e+10             Obesity
# 2  1367284.0           NaN             Obesity
# 3    15003.0  1.500301e+10             Obesity
# 4  1342425.0  1.312101e+10             Obesity
#
# [5 rows x 24 columns]

# %%
group= base.groupby(["StateDesc","CityName"])
meanvalue = group["Data_Value"].mean()

# %%
maxvalue = meanvalue.max()
meanvalue = pd.DataFrame(meanvalue).reset_index()

# %%
meanvalue.loc[(meanvalue["Data_Value"]==maxvalue)]
# Out:
#     StateDesc CityName  Data_Value
# 240   Indiana     Gary   50.042424

# %%
meanvalue
# Out:
#      StateDesc    CityName  Data_Value
# 0      Alabama  Birmingham   40.329348
# 1      Alabama      Hoover   29.160000
# 2      Alabama  Huntsville   35.896667
# 3      Alabama      Mobile   38.803896
# 4      Alabama  Montgomery   39.204839
# ..         ...         ...         ...
# 495  Wisconsin     Madison   26.304478
# 496  Wisconsin   Milwaukee   35.874299
# 497  Wisconsin      Racine   39.504167
# 498  Wisconsin    Waukesha   30.763636
# 499    Wyoming    Cheyenne   29.205556
#
# [500 rows x 3 columns]

# %%
USDA = pd.read_csv('../data/USDA_Farmers_Market.csv')
USDA.head()
# Out:
#       FMID                                        MarketName  \
# 0  1018261   Caledonia Farmers Market Association - Danville
# 1  1018318                 Stearns Homestead Farmers' Market
# 2  1009364                 106 S. Main Street Farmers Market
# 3  1010691               10th Steet Community Farmers Market
# 4  1002454                              112st Madison Avenue
#
#                                              Website  \
# 0  https://sites.google.com/site/caledoniafarmers...
# 1                    http://www.StearnsHomestead.com
# 2             http://thetownofsixmile.wordpress.com/
# 3                                                NaN
# 4                                                NaN
#
#                                             Facebook Twitter Youtube  \
# 0  https://www.facebook.com/Danville.VT.Farmers.M...     NaN     NaN
# 1                      StearnsHomesteadFarmersMarket     NaN     NaN
# 2                                                NaN     NaN     NaN
# 3                                                NaN     NaN     NaN
# 4                                                NaN     NaN     NaN
#
#                                           OtherMedia                  street  \
# 0                                                NaN                     NaN
# 1                                                NaN         6975 Ridge Road
# 2                                                NaN      106 S. Main Street
# 3  http://agrimissouri.com/mo-grown/grodetail.php...  10th Street and Poplar
# 4                                                NaN    112th Madison Avenue
#
#    CityName     county  ... Coffee Beans Fruits Grains Juices Mushrooms  \
# 0  Danville  Caledonia  ...      Y     Y      Y      N      N         Y
# 1     Parma   Cuyahoga  ...      N     N      Y      N      N         N
# 2  Six Mile        NaN  ...    NaN   NaN    NaN    NaN    NaN       NaN
# 3     Lamar     Barton  ...      N     N      Y      N      N         N
# 4  New York   New York  ...      N     N      N      N      N         N
#
#   PetFood Tofu WildHarvested     updateTime
# 0       Y    N             N  6/20/17 22:43
# 1       N    N             N  6/21/17 17:15
# 2     NaN  NaN           NaN           2013
# 3       N    N             N  10/28/14 9:49
# 4       N    N             N   3/1/12 10:38
#
# [5 rows x 59 columns]

# %%
merged_df = USDA.merge(meanvalue, how = 'left', on = ['CityName', 'StateDesc'])
merged_df
# Out:
#          FMID                                        MarketName  \
# 0     1018261   Caledonia Farmers Market Association - Danville
# 1     1018318                 Stearns Homestead Farmers' Market
# 2     1009364                 106 S. Main Street Farmers Market
# 3     1010691               10th Steet Community Farmers Market
# 4     1002454                              112st Madison Avenue
# ...       ...                                               ...
# 8811  1004767                    Zia Bernalillo Farmers' Market
# 8812  1018362                         Zimmerman Farmers' Market
# 8813  1012380                        Zion Canyon Farmers Market
# 8814  1004686                         Zionsville Farmers Market
# 8815  1011418                         Zona Rosa Farmers' Market
#
#                                                 Website  \
# 0     https://sites.google.com/site/caledoniafarmers...
# 1                       http://www.StearnsHomestead.com
# 2                http://thetownofsixmile.wordpress.com/
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8811                         http://www.eatfreshnm.org/
# 8812                         http://Pzfarmersmarket.org
# 8813                             http://zionharvest.org
# 8814             http://www.zionsvillefarmersmarket.org
# 8815                                                NaN
#
#                                                Facebook Twitter Youtube  \
# 0     https://www.facebook.com/Danville.VT.Farmers.M...     NaN     NaN
# 1                         StearnsHomesteadFarmersMarket     NaN     NaN
# 2                                                   NaN     NaN     NaN
# 3                                                   NaN     NaN     NaN
# 4                                                   NaN     NaN     NaN
# ...                                                 ...     ...     ...
# 8811   https://www.facebook.com/farmersmarketsnm?ref=hl     NaN     NaN
# 8812                 Princeton-zimmerman farmers market     NaN     NaN
# 8813  https://www.facebook.com/ZionCanyonFarmersMarket/     NaN     NaN
# 8814                                                NaN     NaN     NaN
# 8815                                                NaN     NaN     NaN
#
#                                              OtherMedia  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     http://agrimissouri.com/mo-grown/grodetail.php...
# 4                                                   NaN
# ...                                                 ...
# 8811                                                NaN
# 8812                                                NaN
# 8813                                                NaN
# 8814                                                NaN
# 8815                                                NaN
#
#                           street     CityName      county  ... Beans Fruits  \
# 0                            NaN     Danville   Caledonia  ...     Y      Y
# 1                6975 Ridge Road        Parma    Cuyahoga  ...     N      Y
# 2             106 S. Main Street     Six Mile         NaN  ...   NaN    NaN
# 3         10th Street and Poplar        Lamar      Barton  ...     N      Y
# 4           112th Madison Avenue     New York    New York  ...     N      N
# ...                          ...          ...         ...  ...   ...    ...
# 8811    335 S. Camino del Pueblo   Bernalillo    Sandoval  ...     Y      Y
# 8812           25850 Main Street    Zimmerman   Sherburne  ...     N      Y
# 8813        1212 Zion Park Blvd.   Springdale  Washington  ...     N      Y
# 8814     Hawthorne & Main Street   Zionsville       Boone  ...   NaN    NaN
# 8815  Off of I-29 and Barry Road  Kansas City      Platte  ...     N      Y
#
#      Grains Juices Mushrooms PetFood Tofu WildHarvested     updateTime  \
# 0         N      N         Y       Y    N             N  6/20/17 22:43
# 1         N      N         N       N    N             N  6/21/17 17:15
# 2       NaN    NaN       NaN     NaN  NaN           NaN           2013
# 3         N      N         N       N    N             N  10/28/14 9:49
# 4         N      N         N       N    N             N   3/1/12 10:38
# ...     ...    ...       ...     ...  ...           ...            ...
# 8811      N      N         N       N    N             N   6/5/14 14:40
# 8812      N      N         N       N    N             N  6/22/17 19:37
# 8813      N      N         Y       N    N             N   7/9/16 17:00
# 8814    NaN    NaN       NaN     NaN  NaN           NaN           2009
# 8815      N      N         N       N    N             N    9/4/15 9:48
#
#      Data_Value
# 0           NaN
# 1     29.037500
# 2           NaN
# 3           NaN
# 4     25.034450
# ...         ...
# 8811        NaN
# 8812        NaN
# 8813        NaN
# 8814        NaN
# 8815  36.167949
#
# [8816 rows x 60 columns]

# %%
merged_df=merged_df.dropna(subset=["Data_Value"])
merged_df
# Out:
#          FMID                                   MarketName  \
# 1     1018318            Stearns Homestead Farmers' Market
# 4     1002454                         112st Madison Avenue
# 5     1011100                      12 South Farmers Market
# 6     1009845   125th Street Fresh Connect Farmers' Market
# 7     1005586          12th & Brandywine Urban Farm Market
# ...       ...                                          ...
# 8791  1019247  Your Neighborhood Farmers Market-CityCentre
# 8794  1019250  Your Neighborhood Farmers Market-Summerwood
# 8798  1007324                                Youth Stands!
# 8799  1007325                                Youth Stands!
# 8815  1011418                    Zona Rosa Farmers' Market
#
#                                            Website  \
# 1                  http://www.StearnsHomestead.com
# 4                                              NaN
# 5              http://www.12southfarmersmarket.com
# 6          http://www.125thStreetFarmersMarket.com
# 7                                              NaN
# ...                                            ...
# 8791  http://www.YourNeighborhoodFarmersMarket.com
# 8794  http://www.YourNeighborhoodFarmersMarket.com
# 8798                http://www.urbangreenworks.org
# 8799                http://www.urbangreenworks.org
# 8815                                           NaN
#
#                                                Facebook  \
# 1                         StearnsHomesteadFarmersMarket
# 4                                                   NaN
# 5                               12_South_Farmers_Market
# 6     https://www.facebook.com/125thStreetFarmersMarket
# 7     https://www.facebook.com/pages/12th-Brandywine...
# ...                                                 ...
# 8791  https://www.facebook.com/yourneighborhoodfarme...
# 8794  https://www.facebook.com/yourneighborhoodfarme...
# 8798                                                NaN
# 8799                                                NaN
# 8815                                                NaN
#
#                                   Twitter Youtube  \
# 1                                     NaN     NaN
# 4                                     NaN     NaN
# 5                         @12southfrmsmkt     NaN
# 6     https://twitter.com/FarmMarket125th     NaN
# 7                                     NaN     NaN
# ...                                   ...     ...
# 8791                                  NaN     NaN
# 8794                                  NaN     NaN
# 8798                                  NaN     NaN
# 8799                                  NaN     NaN
# 8815                                  NaN     NaN
#
#                                              OtherMedia  \
# 1                                                   NaN
# 4                                                   NaN
# 5                                       @12southfrmsmkt
# 6                 Instagram--> 125thStreetFarmersMarket
# 7     https://www.facebook.com/delawareurbanfarmcoal...
# ...                                                 ...
# 8791                                                NaN
# 8794                                                NaN
# 8798                                                NaN
# 8799                                                NaN
# 8815                                                NaN
#
#                                                  street       CityName  \
# 1                                       6975 Ridge Road          Parma
# 4                                  112th Madison Avenue       New York
# 5                                3000 Granny White Pike      Nashville
# 6     163 West 125th Street and Adam Clayton Powell,...       New York
# 7                             12th & Brandywine Streets     Wilmington
# ...                                                 ...            ...
# 8791                         800 Towne and County BLVD.        Houston
# 8794                    14303 West Lake Houston Parkway        Houston
# 8798                                    8240 NW 7th Ave          Miami
# 8799                                  15700 NW 20th Ave  Miami Gardens
# 8815                         Off of I-29 and Barry Road    Kansas City
#
#           county  ... Beans Fruits Grains Juices Mushrooms PetFood Tofu  \
# 1       Cuyahoga  ...     N      Y      N      N         N       N    N
# 4       New York  ...     N      N      N      N         N       N    N
# 5       Davidson  ...     N      Y      N      Y         Y       Y    N
# 6       New York  ...     N      Y      N      Y         N       N    N
# 7     New Castle  ...     N      Y      N      N         N       N    N
# ...          ...  ...   ...    ...    ...    ...       ...     ...  ...
# 8791      Harris  ...     N      Y      N      Y         N       Y    N
# 8794      Harris  ...     Y      Y      Y      Y         N       Y    N
# 8798  Miami-Dade  ...     N      N      N      N         N       N    N
# 8799  Miami-Dade  ...     N      N      N      N         N       N    N
# 8815      Platte  ...     N      Y      N      N         N       N    N
#
#      WildHarvested     updateTime Data_Value
# 1                N  6/21/17 17:15  29.037500
# 4                N   3/1/12 10:38  25.034450
# 5                N   5/1/15 10:40  31.698101
# 6                N   4/7/14 16:32  25.034450
# 7                N   4/3/14 15:43  39.573077
# ...            ...            ...        ...
# 8791             Y   9/6/18 17:06  34.130144
# 8794             Y   9/6/18 17:23  34.130144
# 8798             N  5/22/12 23:19  33.482524
# 8799             N  5/22/12 23:19  37.864000
# 8815             N    9/4/15 9:48  36.167949
#
# [1813 rows x 60 columns]

# %%
fig1, ax1 = plt.subplots()
ax1.boxplot(merged_df["Data_Value"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1aac0a53e48>,
#   <matplotlib.lines.Line2D at 0x1aac0a5b708>],
#  'caps': [<matplotlib.lines.Line2D at 0x1aac0a5bfc8>,
#   <matplotlib.lines.Line2D at 0x1aac0a69f48>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1aac0a47988>],
#  'medians': [<matplotlib.lines.Line2D at 0x1aac0a71f48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1aac0a6f9c8>],
#  'means': []}

# %%
quartiles = merged_df["Data_Value"].quantile([.1,.5,.9])
lowerq = quartiles[0.1]
upperq = quartiles[0.9]
iqr = upperq-lowerq
print(f"The lower quartile is: {lowerq}")
print(f"The upper quartile is: {upperq}")
print(f"The interquartile range is: {iqr}")
print(f"The the median is: {quartiles[0.5]} ")

#lower_bound = lowerq - (1.5*iqr)
#upper_bound = upperq + (1.5*iqr)
#print(f"Values below {lower_bound} could be outliers.")
#print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile is: 22.525
# The upper quartile is: 38.289772998805226
# The interquartile range is: 15.764772998805228
# The the median is: 31.074358974358972

# %%
merged_df.loc[(merged_df["Data_Value"]>=38.289772998805226)]
# Out:
#          FMID                                 MarketName  \
# 7     1005586        12th & Brandywine Urban Farm Market
# 27    1009959  2nd Street Market - Five Rivers MetroPark
# 31    1005636         32nd Street/Waverly Farmers Market
# 36    1011213                  441 Ministries Farm Stand
# 93    1011214            Aenon Baptist Church Farm Stand
# ...       ...                                        ...
# 8498  1012295   Westgate Farmers' Market @ Elder Beerman
# 8519  1004922                    Westside Farmers Market
# 8556  1019392          Whitehaven Kulliye Farmers Market
# 8617  1005613                  Wilmington Farmers Market
# 8639  1002227                    Windmill Farmers Market
#
#                                                 Website  \
# 7                                                   NaN
# 27                            http://www.metroparks.org
# 31                      http://www.32ndstreetmarket.org
# 36                                                  NaN
# 93                                                  NaN
# ...                                                 ...
# 8498                 http://www.toledofarmersmarket.com
# 8519             http://www.westsidemarketrochester.com
# 8556             https://whitehavenkulliye.org/the-suq/
# 8617                     http://www.downtownvisions.org
# 8639  http://www.windmill-market.comwww.windmill-mar...
#
#                                                Facebook  \
# 7     https://www.facebook.com/pages/12th-Brandywine...
# 27            https://www.facebook.com/2ndStreetMarket/
# 31    https://www.facebook.com/pages/Baltimores-32nd...
# 36                                                  NaN
# 93                                                  NaN
# ...                                                 ...
# 8498                              Toledo Farmers Market
# 8519   https://www.facebook.com/westsidemarketrochester
# 8556                                                NaN
# 8617                                                NaN
# 8639                                                NaN
#
#                                Twitter Youtube  \
# 7                                  NaN     NaN
# 27                                 NaN     NaN
# 31                                 NaN     NaN
# 36                                 NaN     NaN
# 93                                 NaN     NaN
# ...                                ...     ...
# 8498                               NaN     NaN
# 8519  https://twitter.com/westsideroch     NaN
# 8556                               NaN     NaN
# 8617                               NaN     NaN
# 8639                               NaN     NaN
#
#                                              OtherMedia  \
# 7     https://www.facebook.com/delawareurbanfarmcoal...
# 27                                                  NaN
# 31                                                  NaN
# 36                                                  NaN
# 93                                                  NaN
# ...                                                 ...
# 8498                                                NaN
# 8519                                                NaN
# 8556                                                NaN
# 8617                                                NaN
# 8639                                                NaN
#
#                                             street    CityName      county  \
# 7                        12th & Brandywine Streets  Wilmington  New Castle
# 27                               600 E. 2nd Street      Dayton  Montgomery
# 31                        E. 32nd & Barclay Street   Baltimore   Baltimore
# 36                             441 Parsells Avenue   Rochester      Monroe
# 93                              175 Genesee Street   Rochester      Monroe
# ...                                            ...         ...         ...
# 8498                               3300 Secor Road      Toledo       Lucas
# 8519                            831 Genesee Street   Rochester      Monroe
# 8556                          3379 Millbranch Road     Memphis      Shelby
# 8617                         N King St. & 11th St.  Wilmington         NaN
# 8639  Livernois  between Lodge Freeway and Fenkell     Detroit       Wayne
#
#       ... Beans Fruits Grains Juices Mushrooms PetFood Tofu WildHarvested  \
# 7     ...     N      Y      N      N         N       N    N             N
# 27    ...     Y      Y      Y      Y         Y       Y    N             Y
# 31    ...     N      Y      N      N         N       N    N             N
# 36    ...     N      Y      N      N         N       N    N             N
# 93    ...     N      Y      N      N         N       N    N             N
# ...   ...   ...    ...    ...    ...       ...     ...  ...           ...
# 8498  ...     N      Y      N      Y         N       N    N             N
# 8519  ...     N      Y      N      Y         N       N    N             N
# 8556  ...     N      Y      Y      Y         N       N    N             Y
# 8617  ...   NaN    NaN    NaN    NaN       NaN     NaN  NaN           NaN
# 8639  ...     N      N      N      N         N       N    N             N
#
#          updateTime Data_Value
# 7      4/3/14 15:43  39.573077
# 27    7/26/18 16:26  42.967797
# 31    7/26/18 16:47  39.562189
# 36      6/8/15 9:22  38.325926
# 93      6/8/15 9:24  38.325926
# ...             ...        ...
# 8498    7/7/16 9:47  44.304950
# 8519  6/27/16 13:41  38.325926
# 8556  2/17/19 10:22  39.291111
# 8617           2011  39.573077
# 8639  4/20/11 14:20  44.812245
#
# [182 rows x 60 columns]

# %%
meanvalue.loc[(meanvalue["Data_Value"]>=38.289772998805226)].count()
# Out:
# StateDesc     45
# CityName      45
# Data_Value    45
# dtype: int64

# %%
c_merged_df= merged_df.drop(columns=["FMID","Website","Facebook","Twitter","Youtube","OtherMedia","street","updateTime",
                                   "Season1Date","Season1Time","Season2Date","Season2Time","Season3Date","Season3Time",
                                    "Season4Date","Season4Time",'Location', 'Credit', 'WIC', 'WICcash'])

# %%
c_merged_df.columns
# Out:
# Index(['MarketName', 'CityName', 'county', 'StateDesc', 'zip', 'Season4Date',
#        'Season4Time', 'x', 'y', 'Location', 'Credit', 'WIC', 'WICcash',
#        'SFMNP', 'SNAP', 'Organic', 'Bakedgoods', 'Cheese', 'Crafts', 'Flowers',
#        'Eggs', 'Seafood', 'Herbs', 'Vegetables', 'Honey', 'Jams', 'Maple',
#        'Meat', 'Nursery', 'Nuts', 'Plants', 'Poultry', 'Prepared', 'Soap',
#        'Trees', 'Wine', 'Coffee', 'Beans', 'Fruits', 'Grains', 'Juices',
#        'Mushrooms', 'PetFood', 'Tofu', 'WildHarvested', 'Data_Value'],
#       dtype='object')

# %%
top = c_merged_df.loc[(c_merged_df["Data_Value"]>=38.289772998805226)]
low = c_merged_df.loc[(c_merged_df["Data_Value"]<=22.525)]

# %%
top["Organic"].value_counts()
# Out:
# -    84
# Y    57
# N    41
# Name: Organic, dtype: int64
